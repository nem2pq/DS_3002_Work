# %% [markdown]
# 1. Required Imports

# %%
import json
import requests
import requests.exceptions
import csv
import pandas as pd

# %% [markdown]
# Below, please change the pathname to a path where you would like all files create by this code to be saved.

# %%
pathname = "/Users/noahmcintire/Documents/DS 3002/"

# %% [markdown]
# 2. Api Response function from 08 Python-API-Data
# This includes extensive try, catch blocks, which will help catch errors if the url given is invalid (rubric ii).

# %%
def get_api_response(url, response_type):
    try:
        response = requests.get(url)
        response.raise_for_status()
    
    except requests.exceptions.HTTPError as errh:
        return "An Http Error occurred: " + repr(errh)
    except requests.exceptions.ConnectionError as errc:
        return "An Error Connecting to the API occurred: " + repr(errc)
    except requests.exceptions.Timeout as errt:
        return "A Timeout Error occurred: " + repr(errt)
    except requests.exceptions.RequestException as err:
        return "An Unknown Error occurred: " + repr(err)

    if response_type == 'json':
        result = json.dumps(response.json(), sort_keys=True, indent=4)
    elif response_type == 'dataframe':
        result = pd.json_normalize(response.json())
    else:
        result = "An unhandled error has occurred!"
        
    return result

# %% [markdown]
# 3. Fetching Data from a pre-defined data source.

# %%
fruit_url = "https://www.fruityvice.com/api/fruit/all"
response_type = "json"

# %%
json_string = get_api_response(fruit_url, response_type)
print(json_string)
# Out:
# [
#     {
#         "family": "Rosaceae",
#         "genus": "Malus",
#         "id": 6,
#         "name": "Apple",
#         "nutritions": {
#             "calories": 52,
#             "carbohydrates": 11.4,
#             "fat": 0.4,
#             "protein": 0.3,
#             "sugar": 10.3
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Prunus",
#         "id": 35,
#         "name": "Apricot",
#         "nutritions": {
#             "calories": 15,
#             "carbohydrates": 3.9,
#             "fat": 0.1,
#             "protein": 0.5,
#             "sugar": 3.2
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Musaceae",
#         "genus": "Musa",
#         "id": 1,
#         "name": "Banana",
#         "nutritions": {
#             "calories": 96,
#             "carbohydrates": 22,
#             "fat": 0.2,
#             "protein": 1,
#             "sugar": 17.2
#         },
#         "order": "Zingiberales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Rubus",
#         "id": 64,
#         "name": "Blackberry",
#         "nutritions": {
#             "calories": 40,
#             "carbohydrates": 9,
#             "fat": 0.4,
#             "protein": 1.3,
#             "sugar": 4.5
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Fragaria",
#         "id": 33,
#         "name": "Blueberry",
#         "nutritions": {
#             "calories": 29,
#             "carbohydrates": 5.5,
#             "fat": 0.4,
#             "protein": 0,
#             "sugar": 5.4
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Prunus",
#         "id": 9,
#         "name": "Cherry",
#         "nutritions": {
#             "calories": 50,
#             "carbohydrates": 12,
#             "fat": 0.3,
#             "protein": 1,
#             "sugar": 8
#         },
#         "order": "None"
#     },
#     {
#         "family": "Malvaceae",
#         "genus": "Durio",
#         "id": 60,
#         "name": "Durian",
#         "nutritions": {
#             "calories": 147,
#             "carbohydrates": 27.1,
#             "fat": 5.3,
#             "protein": 1.5,
#             "sugar": 6.75
#         },
#         "order": "Malvales"
#     },
#     {
#         "family": "Moraceae",
#         "genus": "Ficus",
#         "id": 68,
#         "name": "Fig",
#         "nutritions": {
#             "calories": 74,
#             "carbohydrates": 19,
#             "fat": 0.3,
#             "protein": 0.8,
#             "sugar": 16
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Grossulariaceae",
#         "genus": "Ribes",
#         "id": 69,
#         "name": "Gooseberry",
#         "nutritions": {
#             "calories": 44,
#             "carbohydrates": 10,
#             "fat": 0.6,
#             "protein": 0.9,
#             "sugar": 0
#         },
#         "order": "Saxifragales"
#     },
#     {
#         "family": "Vitaceae",
#         "genus": "Vitis",
#         "id": 47,
#         "name": "Grapes",
#         "nutritions": {
#             "calories": 69,
#             "carbohydrates": 18.1,
#             "fat": 0.16,
#             "protein": 0.72,
#             "sugar": 15.48
#         },
#         "order": "Vitales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Malus",
#         "id": 72,
#         "name": "GreenApple",
#         "nutritions": {
#             "calories": 21,
#             "carbohydrates": 3.1,
#             "fat": 0.1,
#             "protein": 0.4,
#             "sugar": 6.4
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Myrtaceae",
#         "genus": "Psidium",
#         "id": 37,
#         "name": "Guava",
#         "nutritions": {
#             "calories": 68,
#             "carbohydrates": 14,
#             "fat": 1,
#             "protein": 2.6,
#             "sugar": 9
#         },
#         "order": "Myrtales"
#     },
#     {
#         "family": "Actinidiaceae",
#         "genus": "Apteryx",
#         "id": 66,
#         "name": "Kiwi",
#         "nutritions": {
#             "calories": 61,
#             "carbohydrates": 15,
#             "fat": 0.5,
#             "protein": 1.1,
#             "sugar": 9
#         },
#         "order": "Struthioniformes"
#     },
#     {
#         "family": "Rutaceae",
#         "genus": "Citrus",
#         "id": 26,
#         "name": "Lemon",
#         "nutritions": {
#             "calories": 29,
#             "carbohydrates": 9,
#             "fat": 0.3,
#             "protein": 1.1,
#             "sugar": 2.5
#         },
#         "order": "Sapindales"
#     },
#     {
#         "family": "Rutaceae",
#         "genus": "Citrus",
#         "id": 44,
#         "name": "Lime",
#         "nutritions": {
#             "calories": 25,
#             "carbohydrates": 8.4,
#             "fat": 0.1,
#             "protein": 0.3,
#             "sugar": 1.7
#         },
#         "order": "Sapindales"
#     },
#     {
#         "family": "Ericaceae",
#         "genus": "Vaccinium",
#         "id": 65,
#         "name": "Lingonberry",
#         "nutritions": {
#             "calories": 50,
#             "carbohydrates": 11.3,
#             "fat": 0.34,
#             "protein": 0.75,
#             "sugar": 5.74
#         },
#         "order": "Ericales"
#     },
#     {
#         "family": "Sapindaceae",
#         "genus": "Litchi",
#         "id": 67,
#         "name": "Lychee",
#         "nutritions": {
#             "calories": 66,
#             "carbohydrates": 17,
#             "fat": 0.44,
#             "protein": 0.8,
#             "sugar": 15
#         },
#         "order": "Sapindales"
#     },
#     {
#         "family": "Anacardiaceae",
#         "genus": "Mangifera",
#         "id": 27,
#         "name": "Mango",
#         "nutritions": {
#             "calories": 60,
#             "carbohydrates": 15,
#             "fat": 0.38,
#             "protein": 0.82,
#             "sugar": 13.7
#         },
#         "order": "Sapindales"
#     },
#     {
#         "family": "Cucurbitaceae",
#         "genus": "Cucumis",
#         "id": 41,
#         "name": "Melon",
#         "nutritions": {
#             "calories": 34,
#             "carbohydrates": 8,
#             "fat": 0,
#             "protein": 0,
#             "sugar": 8
#         },
#         "order": "Cucurbitaceae"
#     },
#     {
#         "family": "Rutaceae",
#         "genus": "Citrus",
#         "id": 2,
#         "name": "Orange",
#         "nutritions": {
#             "calories": 43,
#             "carbohydrates": 8.3,
#             "fat": 0.2,
#             "protein": 1,
#             "sugar": 8.2
#         },
#         "order": "Sapindales"
#     },
#     {
#         "family": "Caricaceae",
#         "genus": "Carica",
#         "id": 42,
#         "name": "Papaya",
#         "nutritions": {
#             "calories": 43,
#             "carbohydrates": 11,
#             "fat": 0.4,
#             "protein": 0,
#             "sugar": 1
#         },
#         "order": "Caricacea"
#     },
#     {
#         "family": "Passifloraceae",
#         "genus": "Passiflora",
#         "id": 70,
#         "name": "Passionfruit",
#         "nutritions": {
#             "calories": 97,
#             "carbohydrates": 22.4,
#             "fat": 0.7,
#             "protein": 2.2,
#             "sugar": 11.2
#         },
#         "order": "Malpighiales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Pyrus",
#         "id": 4,
#         "name": "Pear",
#         "nutritions": {
#             "calories": 57,
#             "carbohydrates": 15,
#             "fat": 0.1,
#             "protein": 0.4,
#             "sugar": 10
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Ebenaceae",
#         "genus": "Diospyros",
#         "id": 52,
#         "name": "Persimmon",
#         "nutritions": {
#             "calories": 81,
#             "carbohydrates": 18,
#             "fat": 0,
#             "protein": 0,
#             "sugar": 18
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Bromeliaceae",
#         "genus": "Ananas",
#         "id": 10,
#         "name": "Pineapple",
#         "nutritions": {
#             "calories": 50,
#             "carbohydrates": 13.12,
#             "fat": 0.12,
#             "protein": 0.54,
#             "sugar": 9.85
#         },
#         "order": "Poales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Prunus",
#         "id": 71,
#         "name": "Plum",
#         "nutritions": {
#             "calories": 46,
#             "carbohydrates": 11.4,
#             "fat": 0.28,
#             "protein": 0.7,
#             "sugar": 9.92
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Rubus",
#         "id": 23,
#         "name": "Raspberry",
#         "nutritions": {
#             "calories": 53,
#             "carbohydrates": 12,
#             "fat": 0.7,
#             "protein": 1.2,
#             "sugar": 4.4
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Rosaceae",
#         "genus": "Fragaria",
#         "id": 3,
#         "name": "Strawberry",
#         "nutritions": {
#             "calories": 29,
#             "carbohydrates": 5.5,
#             "fat": 0.4,
#             "protein": 0.8,
#             "sugar": 5.4
#         },
#         "order": "Rosales"
#     },
#     {
#         "family": "Solanaceae",
#         "genus": "Solanum",
#         "id": 5,
#         "name": "Tomato",
#         "nutritions": {
#             "calories": 74,
#             "carbohydrates": 3.9,
#             "fat": 0.2,
#             "protein": 0.9,
#             "sugar": 2.6
#         },
#         "order": "Solanales"
#     },
#     {
#         "family": "Anacardiaceae",
#         "genus": "Spondias",
#         "id": 73,
#         "name": "Umbu",
#         "nutritions": {
#             "calories": 0,
#             "carbohydrates": 0,
#             "fat": 0,
#             "protein": 0,
#             "sugar": 0
#         },
#         "order": "0"
#     },
#     {
#         "family": "Cucurbitaceae",
#         "genus": "Citrullus",
#         "id": 25,
#         "name": "Watermelon",
#         "nutritions": {
#             "calories": 30,
#             "carbohydrates": 8,
#             "fat": 0.2,
#             "protein": 0.6,
#             "sugar": 6
#         },
#         "order": "Cucurbitales"
#     }
# ]

# %%
json_path=r""+pathname+"fruits.json"
json_file=open(json_path, "w")
json_file.write(json_string)
json_file.close()

# %% [markdown]
# 4. Converting to a CSV to modify columns
#
# If the desired data structure of info from the api is a CSV, run the following cells below. By doing so, we are able to remove the order column from CSV. Additional info about the data can be discovered by running df.info(). This includes both the entries (records) and columns present in the dataset (benchmark i5 in the rubric).

# %%
df = pd.read_json(json_path)
df.to_csv(r""+ pathname + "/fruit.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   family      31 non-null     object
#  1   genus       31 non-null     object
#  2   id          31 non-null     int64
#  3   name        31 non-null     object
#  4   nutritions  31 non-null     object
#  5   order       31 non-null     object
# dtypes: int64(1), object(5)
# memory usage: 1.6+ KB

# %%
df.head()
# Out:
#      family     genus  id        name  \
# 0  Rosaceae     Malus   6       Apple
# 1  Rosaceae    Prunus  35     Apricot
# 2  Musaceae      Musa   1      Banana
# 3  Rosaceae     Rubus  64  Blackberry
# 4  Rosaceae  Fragaria  33   Blueberry
#
#                                           nutritions         order
# 0  {'calories': 52, 'carbohydrates': 11.4, 'fat':...       Rosales
# 1  {'calories': 15, 'carbohydrates': 3.9, 'fat': ...       Rosales
# 2  {'calories': 96, 'carbohydrates': 22, 'fat': 0...  Zingiberales
# 3  {'calories': 40, 'carbohydrates': 9, 'fat': 0....       Rosales
# 4  {'calories': 29, 'carbohydrates': 5.5, 'fat': ...       Rosales

# %% [markdown]
# Droping the order column using the df.drop(0) function.

# %%
df.drop('order',inplace=True, axis=1)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31 entries, 0 to 30
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   family      31 non-null     object
#  1   genus       31 non-null     object
#  2   id          31 non-null     int64
#  3   name        31 non-null     object
#  4   nutritions  31 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.3+ KB

# %% [markdown]
# We can now write this file to the same location as the orignal CSV to update it (rubric i4).

# %%
df.to_csv(r""+ pathname + "/fruit.csv")
